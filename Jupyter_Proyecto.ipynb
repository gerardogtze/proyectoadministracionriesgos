# %% [markdown]
# <img style="float: left; margin: 30px 15px 15px 15px;" src="https://oci02.img.iteso.mx/Identidades-De-Instancia/ITESO/Logos%20ITESO/Logo-ITESO-Principal.jpg" width="400" height="600" />
#
#
# #### <font color='navy'> Proyecto. Administración de Riesgos.
#
# #### <font color='navy'> Cómite de Inversión y Riesgos.
#
#
# Alumnos: Gerardo Gutierrez Estrada
#
# Profesor: Sean Nicolás González Vázquez.

# %% [markdown]
# ### Objetivos.
#
# > Realizar un proyecto que ayude a un cómite a tomar una decisión de inversión, seleccionando correctamente para un nicho de inversionistas *x* cantidad de activos financieros, además de optimizar y simular el comportamiento del portafolio y posteriormente analizar los riesgos (mercado, operativo y liquidez) del portafolio.
#
# ### Definición el proyecto.
#
# El proyecto constará de las siguientes seis partes, las cuales cuentan con una ponderación específica y serán definidas posteriormente.
#
# |                           | Ponderacion |
# |---------------------------|-------------|
# | 1. Selección de Activos   | 20%         |
# | 2. Obtención de Datos     | 10%         |
# | 3. Optimizacion y Evolución| 10%         |
# | 4. Metricas de Desempeño  | 10%         |
# | 5. Riesgo                 | 30%         |
# | 6. Presentacion           | 20%         |

# %% [markdown]
# ## <font color = "navy"> Parte 1. Selección de Activos <font color = "black">
#
# + Seleccionar de 4 a 6 activos financieros que coticen en bolsa, sientanse libres de utilizar ETF's o acciones.
#
#
# + Justificar la selección de cada uno de los activos con métricas financieras, ya sea con Análisis Técnico o Análisis Fundamental (PER, BPA, EBITDA, Beta). En esta parte se tiene que justificar la selección de la mejor manera posible, incluyendo todo lo que debamos saber acerca del instrumento, es decir, hacer una investigación acerca de las características de las empresas, expectativas, planes a futuro.
#
# Ejemplo: Lo ideal sería seleccionar activos con, por ejemplo PER bajo, pero, si se quiere seleccionar por ejemplo Tesla, comentar todo lo que tiene planeado TESLA para el futuro, además de la perspectiva de mercado para la empresa, lo que causa una sobrevaluación de mercado.
#
# + Comentar acerca de la coyuntura económica.
#
# + Se debe comentar el horizonte de inversión recomendado y el perfil de inversión al que se dirige nuestro portafolio.
#
# **Productos Esperados**: Se muestran los activos elegidos, cada uno con sus respectivas justificaciones y características.
#
# ##  <font color = "navy">  Parte 2. Obtención de Datos <font color = "black">
#
# + Bajar de **FactSet** o de la **API de Yahoo Finance** el precio de cierre ajustado y volumen de los activos seleccionados.
#
#
# + Calcular los rendimientos de tus activos con el cierre de precio ajustado.
#
#
# + Presentar los precios, volumen y rendimientos en un DataFrame. Bajarlos del `01-01-2021` al `12-31-2022`.
#
#
# **Productos Esperados**: Data Frame con los precios, volumen y rendimientos de los activos seleccionados.
#
#
# ##   <font color = "navy">  Parte 3. Optimización de Sharpe y Evolución del Portafolio. <font color = "black">
#
# + Con los rendimientos obtenidos en la parte anterior, obtener las ponderaciones eficientes de sharpe, utilizando como ventana de optimización del `01-01-2021` al `12-31-2021`.
#
#
# + Simular el comportamiento de tu portafolio (rendimientos y evolución del dinero) para el período posterior (`01-01-2022` al `12-31-2022`) y presentarlo en un dataframe. Asumir un capital inicial de $1,000,000 de USD.
#
#
# **Productos Esperados**: Ponderaciones óptimas de Sharpe. Dos Data Frames uno con los rendimientos de tu portafolio y otro con la evolución del valor de tu portafolio. Graficar la evolución del portafolio.
#
#
# ##  <font color = "navy">  Parte 4. Métricas de Desempeño. <font color = "black">
#
# + Armar un data frame que muestre las siguientes métricas de tu portafolio: Rendimiento Esperado, Volatilidad, Ratio de Sharpe y Alpha de Jensen. Se espera que al menos, el Ratio de Sharpe sea positivo.
#
#
# + Comentar acerca de estos, ¿Cuál es la fórmula? ¿Que miden? ¿Que significan los resultados encontrados?.
#
#
# **Productos Esperados**: Data Frame con Métricas de Desempeño y comentar los resultados.
#
#
# ##  <font color = "navy">  Parte 5. Riesgo. <font color = "black">
#
# + Calcular el VaR y el ES a un día con 99% de confianza de tu portafolio. Concluir acerca de este.
#
#
# + Responder en base al volumen promedio de cada activo en los últimos 3 meses, ¿Cuántos días tardarías en deshacer tu posición en cada uno en caso de que vendas todo tu portafolio?
#
#
# + Calcular el VaR en dinero y responder: ¿Si tu límite de VaR es del 10% del valor de tu portafolio (100,000), como administrador de portafolios, ¿Que harías para cumplir el límite de VaR, si lo estas pasando o en el futuro lo pasas? Propon una estrategia específica y clara.
#
#
# + Mostrar la matriz de correlación de los activos de tu portafolio y concluir acerca de los riesgos y/o beneficios que tienes con la diversificación de tu portafolio.
#
#
# + Realizar una investigación acerca de los riesgos individuales más importantes de cada acción. ¿Que pudiera suceder en los siguientes meses que afecte el precio de la acción? ¿Que factores económico-políticos podrían presionar la acción? ¿Tiene algún riesgo específico de operación en el corto plazo?
#
# **Productos Esperados**: VaR, ES, matriz de correlación e investigación.
#
# ##  <font color = "navy">  Parte 6. Presentación. <font color = "black">
#
# Armar en un jupyter notebook una presentación **organizada y concreta por secciones** con todos los puntos, el producto se presenta frente al grupo (*10 a 12 minutos*) y se convence de que es buena idea invertir en el portafolio planteado.

# %% [markdown]
# ### Parte 1
# ||XOM|ALV.DE|BOTA.L|0R1G.IL|DGE.L|JNJ.DE|
# |---|---|---|---|---|---|---|
# |Divisa|USD|EUR|GBP|USD|GBP|EUR|
# |Volumen|16926745|1079232|57787|23438|4481507|3945|
# |Beta|1.08|1.14|0.82|0.93|0.36|0.53|
# |P/E|7.8|12.73|9.2|10.69|22.78|22.47|
# |Yield|3.64|11.4|0.08|8.36|0.78|4.23|
#
# &emsp; La selección de nuestros activos se basó en un perfil de inversión moderado, por lo que se tomó la Libertad de tener algunos riesgos para apostar por un plus de rentabilidad mientras que el portafolio se mantiene relativamente balanceado, por esta razón se buscó diversificar el portafolio en cuanto a betas y divisas mientras que se monitorearon los volúmenes de los activos para garantizar que se puedan realizar retiros cuando sea pertinente.
#
# El acercamiento a estos activos fue bajo la coyuntura de que el dólar se encuentra inestable y por tanto hay que diversificar las divisas y bajo la misma lógica se decidió seleccionar más activos con beta < 1 ya que el mercado se encuentra en una situación compleja.

# %% [markdown]
# ### Parte 2)

# %%
# %pip install pandas_datareader
# %pip install yfinance
# %pip install scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.3; however, version 23.0.1 is available.
# You should consider upgrading via the 'c:\Users\Fernando\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.3; however, version 23.0.1 is available.
# You should consider upgrading via the 'c:\Users\Fernando\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.3; however, version 23.0.1 is available.
# You should consider upgrading via the 'c:\Users\Fernando\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
import pandas_datareader.data as web
import numpy as np
import yfinance as yf
import scipy.optimize as sco

# %%
# Ejemplo AAPL MSFT cambiar por activos correctos
data = yf.download("XOM ALV.DE BOOT.L PBR DGE.L JNJ.DE", start="2021-01-01", end= "2022-12-31")
rends = ((data['Adj Close'] / data['Adj Close'].shift(1) - 1).fillna(0))*100

data['Rendimiento XOM']= rends["XOM"]
data['Rendimiento XOM']=data['Rendimiento XOM'].round(2)
data['Rendimiento XOM']=data['Rendimiento XOM'].astype(str)+ '%'

data['Rendimiento ALV.DE']= rends["ALV.DE"]
data['Rendimiento ALV.DE']=data['Rendimiento ALV.DE'].round(2)
data['Rendimiento ALV.DE']=data['Rendimiento ALV.DE'].astype(str)+ '%'

data['Rendimiento BOOT.L']= rends["BOOT.L"]
data['Rendimiento BOOT.L']=data['Rendimiento BOOT.L'].round(2)
data['Rendimiento BOOT.L']=data['Rendimiento BOOT.L'].astype(str)+ '%'

data['Rendimiento PBR']= rends["PBR"]
data['Rendimiento PBR']=data['Rendimiento PBR'].round(2)
data['Rendimiento PBR']=data['Rendimiento PBR'].astype(str)+ '%'

data['Rendimiento DGE.L']= rends["DGE.L"]
data['Rendimiento DGE.L']=data['Rendimiento DGE.L'].round(2)
data['Rendimiento DGE.L']=data['Rendimiento DGE.L'].astype(str)+ '%'

data['Rendimiento JNJ.DE']= rends["JNJ.DE"]
data['Rendimiento JNJ.DE']=data['Rendimiento JNJ.DE'].round(2)
data['Rendimiento JNJ.DE']=data['Rendimiento JNJ.DE'].astype(str)+ '%'



data.drop(columns=["Open", "Close", "Low", "High"])
# Out:
# [*********************100%***********************]  6 of 6 completed
#              Adj Close                                                  \
#                 ALV.DE      BOOT.L        DGE.L      JNJ.DE        PBR
# Date
# 2021-01-04  180.402054  251.606979  2800.878174  118.912979   5.604549
# 2021-01-05  178.549164  249.210693  2798.502930  118.987984   5.769831
# 2021-01-06  187.831772  249.210693  2799.453125  121.612991   5.819916
# 2021-01-07  186.287704  247.293716  2839.832031  121.912994   5.854976
# 2021-01-08  186.878067  244.418213  2886.386719  122.644257   5.854976
# ...                ...         ...          ...         ...        ...
# 2022-12-23  202.199997  233.000000  3615.557861  165.274078  11.090000
# 2022-12-27  203.050003         NaN          NaN  165.432861  10.850000
# 2022-12-28  202.149994  233.000000  3636.373779  165.472565  10.850000
# 2022-12-29  203.699997  235.500000  3635.878174  165.313782  10.680000
# ...

# %% [markdown]
# ### Parte 3)

# %%
rendimientos_portafolio= rends.mean()
volatilidad_portafolio= rends.std().mean()
rf= 0.0338 
sharpe_ratios = (rendimientos_portafolio - rf) / volatilidad_portafolio
sharpe_ratios
# Out:
# ALV.DE   -0.002834
# BOOT.L   -0.008724
# DGE.L     0.007251
# JNJ.DE    0.019298
# PBR       0.086224
# XOM       0.106634
# dtype: float64

# %%
# Calcular los rendimientos diarios de los activos
returns = data["Adj Close"].pct_change()

# Definir la función de utilidad para calcular los retornos, la varianza y el Sharpe Ratio del portafolio
def calcular_rendimiento_portafolio(weights, returns):
    portfolio_return = np.sum(returns.mean() * weights) * 252
    portfolio_volatility = np.sqrt(np.dot(weights.T, np.dot(returns.cov() * 252, weights)))
    sharpe_ratio = portfolio_return / portfolio_volatility
    return np.array([portfolio_return, portfolio_volatility, sharpe_ratio])

# Definir la función de optimización para encontrar el portafolio con el Sharpe Ratio más alto
def optimizacion_sharpe_ratio(returns):
    num_activos = len(returns.columns)
    pesos_iniciales = np.array(num_activos * [1.0 / num_activos])

    # Restricciones de pesos (weights)
    restricciones = ({'type': 'eq', 'fun': lambda x: np.sum(x) - 1},
              {'type': 'ineq', 'fun': lambda x: 0.2 - x[0]},
              {'type': 'ineq', 'fun': lambda x: 0.2 - x[1]},
              {'type': 'ineq', 'fun': lambda x: 0.2 - x[2]},
              {'type': 'ineq', 'fun': lambda x: 0.2 - x[3]},
              {'type': 'ineq', 'fun': lambda x: 0.2 - x[4]},
              {'type': 'ineq', 'fun': lambda x: 0.2 - x[5]})

    # Limites de pesos (weights)
    limites_pesos = tuple((0, 1) for x in range(num_activos))

    # Optimización de Sharpe Ratio
    resultado = sco.minimize(fun=lambda x: -calcular_rendimiento_portafolio(x, returns)[2],
                         x0=pesos_iniciales,
                         method='SLSQP',
                         bounds=limites_pesos,
                         constraints=restricciones)
    return resultado
# Llamar la función de optimización para obtener el portafolio de mayor Sharpe Ratio
opt = optimizacion_sharpe_ratio(returns)['x']
opt_names = {
    'XOM':opt[0],
    'ALV.DE':opt[1],
    'BOOT.L':opt[2],
    'PBR':opt[3],
    'DGE.L':opt[4],
    'JNJ.DE':opt[5],
}
opt_names
# Out:
# {'XOM': 0.15920571199371764,
#  'ALV.DE': 0.09276148754177943,
#  'BOOT.L': 0.20000000000000046,
#  'PBR': 0.19999999999999962,
#  'DGE.L': 0.14803280046450318,
#  'JNJ.DE': 0.1999999999999995}

# %% [markdown]
# ## Parte 4

# %%
# !pip install pandas-datareader

# %%
import pandas_datareader as pdr

data = yf.download("XOM ALV.DE BOOT.L PBR DGE.L JNJ.DE", start="2021-01-01", end= "2022-12-31")
data = data['Adj Close']
# Out:
# [*********************100%***********************]  6 of 6 completed

# %% [markdown]
# {'XOM': 0.15920571199371764,
#  'ALV.DE': 0.09276148754177943,
#  'BOOT.L': 0.20000000000000046,
#  'PBR': 0.19999999999999962,
#  'DGE.L': 0.14803280046450318,
#  'JNJ.DE': 0.1999999999999995}

# %%
#### Usando las ponderaciones que nos dio la parte 3 ponderamos el portafolio. 
portfolio = [.16, .09, 0.2, .20, 0.15, 0.2]
log_return = np.sum(np.log(data/data.shift())*portfolio, axis=1)

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

fig, ax = plt.subplots()
log_return.hist(bins=50, ax=ax)
## tENEMOS QUE LA MAYORIA DE LOS DATOS Estan en una varianza cercana a cero no es muy riesgoso nuestro portafolio.
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:>

# %%
acciones = ['XOM', 'ALV.DE', 'BOOT.L', 'PBR', 'DGE.L', 'JNJ.DE']
ponderaciones = [.16, .09, 0.2, .20, 0.15, 0.2]

portafolio = pd.DataFrame({'Acciones': acciones, 'Ponderaciones': ponderaciones})

# %%
inicio = '2021-01-01'
fin = '2022-12-31'

datos = yf.download(acciones, start=inicio, end=fin)['Adj Close']
# Out:
# [*********************100%***********************]  6 of 6 completed

# %%
#Obtenemos los rendimientos diarios ind y los del portafolio. 
rend_diarios = np.log(datos / datos.shift(1))
rend_portafolio_diarios = (rend_diarios * portafolio['Ponderaciones']).sum(axis=1)
rendimiento_portafolio = (np.exp(rend_portafolio_diarios.cumsum())[-1] - 1) * 100
rendimiento_portafolio
# Out:
# 0.0

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt

# Símbolos de las acciones del portafolio y sus ponderaciones
acciones = ['XOM', 'ALV.DE', 'BOOT.L', 'PBR', 'DGE.L', 'JNJ.DE']
ponderaciones = [.06, .2, 0.14, .20, 0.2, 0.2]

# DataFrame que contiene los símbolos de las acciones y sus ponderaciones
portafolio = pd.DataFrame({'Acciones': acciones, 'Ponderaciones': ponderaciones})

# Obtener precios de cierre ajustados de las acciones del portafolio
inicio = '2021-01-01'
fin = '2022-12-31'
datos = yf.download(acciones, start=inicio, end=fin)['Adj Close']

# Calcular retornos diarios de las acciones del portafolio
retornos_diarios = np.log(datos / datos.shift(1))

# Calcular retornos diarios del portafolio
retornos_portafolio_diarios = (retornos_diarios * portafolio['Ponderaciones']).sum(axis=1)

# Calcular valor inicial del portafolio
valor_inicial = 100000000

# Calcular valor del portafolio para cada día
valor_portafolio = valor_inicial * np.exp(retornos_portafolio_diarios.cumsum())

# Graficar crecimiento del portafolio
plt.plot(valor_portafolio)
plt.xlabel('Fecha')
plt.ylabel('Valor del portafolio')
plt.title('Crecimiento del portafolio')
plt.show()
# Out:
# [*********************100%***********************]  6 of 6 completed

# %%
print(retornos_diarios)
# Out:
#             0R1G.IL    ALV.DE    BOOT.L     DGE.L    JNJ.DE       XOM
# Date
# 2021-01-04      NaN       NaN       NaN       NaN       NaN       NaN
# 2021-01-05      0.0 -0.010324 -0.009570 -0.000848  0.000631  0.047068
# 2021-01-06      0.0  0.050683  0.000000  0.000339  0.021821  0.025197
# 2021-01-07      0.0 -0.008254 -0.007722  0.014321  0.002464  0.007815
# 2021-01-08      0.0  0.003164 -0.011696  0.016260  0.005980  0.011060
# ...             ...       ...       ...       ...       ...       ...
# 2022-12-23      0.0 -0.001729 -0.008547 -0.004240 -0.004553  0.026101
# 2022-12-27      NaN  0.004195       NaN       NaN  0.000960  0.013798
# 2022-12-28      NaN -0.004442       NaN       NaN  0.000240 -0.016563
# 2022-12-29      0.0  0.007638  0.010672 -0.000136 -0.000960  0.007538
# 2022-12-30      0.0 -0.013841 -0.002125 -0.004919 -0.007109  0.010023
#
# [517 rows x 6 columns]

# %%
datos_OR1G = yf.download('OR1G.IL', start=inicio, end=fin)['Adj Close']
retornos_diarios_OR1G = np.log(datos_OR1G / datos_OR1G.shift(1))
print(retornos_diarios_OR1G)
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - OR1G.IL: No timezone found, symbol may be delisted
# Series([], Name: Adj Close, dtype: float64)
